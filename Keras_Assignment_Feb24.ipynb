# %% [markdown]
# # Applied Data Science 2 - Keras Assignment - 2023A
#
# In this assignment you will be building a script to classify movie posters. The assignment is broken up into sections and you need to complete each section successively. The sections are:
#
# 1. Data Processing
# 2. Model Definition
# 3. Model Training
# 4. Model Evaluation
#
# In addition to this coding exercise, you will also need to write a 1-2 page report analysing and critically evaluating you models results.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
import pandas as pd
from sklearn import model_selection
from tensorflow.keras import layers, Model
from tensorflow.keras import losses
from tensorflow.keras.optimizers import Adam
from keras.metrics import Precision, Recall

# %%
# CodeGrade Tag Init1
# Do not edit, remove, or copy this cell

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data Processing

# %%
# CodeGrade Tag Init2
# Do not edit, remove, or copy this cell

# This code will copy the images from your google drive into the colab file
# storage. Make sure the dataset is unzipped in your drive folder.
! mkdir /tmp/Multi_Label_dataset
! rsync -ah --info=progress2 /content/drive/MyDrive/Multi_Label_dataset/Images /tmp/Multi_Label_dataset/
# Out:
# mkdir: cannot create directory ‘/tmp/Multi_Label_dataset’: File exists
#               0   0%    0.00kB/s    0:00:00 (xfr#0, to-chk=0/7946)

# %%
# CodeGrade Tag DataProc
# Do not edit, remove, or copy this cell

# Load the csv with the sample IDs and genres
csv_loc = "/content/drive/MyDrive/Multi_Label_dataset/train.csv"
dataset = pd.read_csv("/content/drive/MyDrive/Multi_Label_dataset/train.csv")

# Split the dataset into training and testing
data_train, data_test = model_selection.train_test_split(dataset, test_size=0.2)

# Convert the labels to arrays
labels_train = np.array(data_train.drop(['Id', 'Genre'],axis=1)).astype('float32')
labels_test = np.array(data_test.drop(['Id', 'Genre'],axis=1)).astype('float32')

# List of the genre names
genres = np.array(data_train.drop(['Id', 'Genre'],axis=1).columns)

# Build the file locations for the images
img_loc = "/tmp/Multi_Label_dataset/Images"

img_locs_train = np.array([[img_loc + '/' + id + '.jpg' for id in data_train['Id']]])
img_locs_test = [[img_loc + '/' + id + '.jpg' for id in data_test['Id']]]


# This function is provided to read in the image files from the folder
def parse_image(filename, label):
  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

# Create the initial datasets
train_list_ds = tf.data.Dataset.from_tensor_slices((img_locs_train[0], labels_train))
test_list_ds = tf.data.Dataset.from_tensor_slices((img_locs_test[0], labels_test))

# %% [markdown]
# **Create a function called "img_process" converts the images to float32 datatype and resizes them to 64x64 pixels.**

# %%
# CodeGrade Tag Ex1a
### Write a function called img_process, which takes in the image and label as
### inputs, converts the data type of the image to tf.float32, resizes the
### image to (64, 64), and finally returns the image and labels.
def img_process(image, label):
    image = tf.image.convert_image_dtype(image, 'float32')
    image = tf.image.resize(image, (64, 64))

    return image, label

# %% [markdown]
# **Using the tf.data API, load in the training and validation data. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1b
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 64. Use techniques like caching and
### prefetching to efficiently load the data.
# Train data
train = (
      train_list_ds
      .map(parse_image, num_parallel_calls= tf.data.AUTOTUNE)
      .batch(64)
      .map(img_process, num_parallel_calls= tf.data.AUTOTUNE)
      .cache()
      .shuffle(buffer_size=1000)
      .prefetch(tf.data.AUTOTUNE)
)


# Validation datasets
test = (
      test_list_ds
      .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
      .batch(64)
      .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)
      .cache()
      .shuffle(buffer_size=1000)
      .prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# # Model Definition
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture show in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a Sigmoid activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.
# * For the dropout layers, use a dropout rate of 0.2 after the convolutional layers and 0.5 after the dense layers.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        448
#
#  Drop1 (Dropout)             (None, 32, 32, 16)        0
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Drop2 (Dropout)             (None, 32, 32, 32)        0
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Drop3 (Dropout)             (None, 16, 16, 64)        0
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  Drop4 (Dropout)             (None, 8, 8, 128)         0
#
#  Pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  Flat (Flatten)              (None, 2048)              0
#
#  FC1 (Dense)                 (None, 1024)              2098176
#
#  Drop5 (Dropout)             (None, 1024)              0
#
#  FC2 (Dense)                 (None, 1024)              1049600
#
#  Drop6 (Dropout)             (None, 1024)              0
#
#  Output (Dense)              (None, 25)                25625
#
# =================================================================
# Total params: 3464601 (13.22 MB)
# Trainable params: 3464601 (13.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.
# Input layer
from tensorflow.keras import layers, Model

# Input layer
inp = layers.Input((64, 64, 3), dtype='float32', name='Input')

# Convolutional layers
conv0 = layers.Conv2D(16, (3, 3), activation='relu', strides=2, padding='same', name='Conv0')(inp)
drop1 = layers.Dropout(0.2, name='Drop1')(conv0)

conv1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same', name='Conv1')(drop1)
conv2 = layers.Conv2D(32, (3, 3), activation='relu', padding='same', name='Conv2')(conv1)
drop2 = layers.Dropout(0.2, name='Drop2')(conv2)

pool1 = layers.MaxPooling2D((2, 2), name='Pool1')(drop2)

conv3 = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='Conv3')(pool1)
conv4 = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='Conv4')(conv3)
drop3 = layers.Dropout(0.2, name='Drop3')(conv4)

pool2 = layers.MaxPooling2D((2, 2), name='Pool2')(drop3)

conv5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='Conv5')(pool2)
conv6 = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='Conv6')(conv5)
drop4 = layers.Dropout(0.2, name='Drop4')(conv6)

pool3 = layers.MaxPooling2D((2, 2), name='Pool3')(drop4)

# Flatten layer
flatten = layers.Flatten(name='Flat')(pool3)

# Fully connected layers
fc1 = layers.Dense(1024, activation='relu', name='FC1')(flatten)
drop5 = layers.Dropout(0.5, name='Drop5')(fc1)

fc2 = layers.Dense(1024, activation='relu', name='FC2')(drop5)
drop6 = layers.Dropout(0.5, name='Drop6')(fc2)

# Output layer
out = layers.Dense(25, activation='sigmoid', name='Output')(drop6)

# Create model
model = Model(inputs=inp, outputs=out)

# %%
# CodeGrade Tag Ex2b
### Print the model summary and confirm is has the same architecture as the one
### provided.
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        448
#
#  Drop1 (Dropout)             (None, 32, 32, 16)        0
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Drop2 (Dropout)             (None, 32, 32, 32)        0
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Drop3 (Dropout)             (None, 16, 16, 64)        0
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  Drop4 (Dropout)             (None, 8, 8, 128)         0
#
#  Pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  Flat (Flatten)              (None, 2048)              0
#
#  FC1 (Dense)                 (None, 1024)              2098176
#
#  Drop5 (Dropout)             (None, 1024)              0
#
#  FC2 (Dense)                 (None, 1024)              1049600
#
#  Drop6 (Dropout)             (None, 1024)              0
#
#  Output (Dense)              (None, 25)                25625
#
# =================================================================
# Total params: 3464601 (13.22 MB)
# Trainable params: 3464601 (13.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Compile the model using the Adam Optimizer with a learning rate of ```1e-4``` and ```binary crossentropy``` loss function. For the metrics, use the ``Precision`` and ``Recall`` functions.**

# %%
# CodeGrade Tag Ex2c
### Compile the model using the Adam Optimizer, binary crossentropy loss, and
### precision and recall metrics.
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss=tf.keras.losses.binary_crossentropy,
              metrics=[Precision(),Recall()])

# %% [markdown]
# # Model Training
#
# **Create a Model Checkpoint Callback that saves the weights of the best performing epoch, based on the validation accuracy.**

# %%
# CodeGrade Tag Ex3a
### Create a ModelCheckpoint callback to store the bext weights from the model,
### based on the validation accuracy. Call this callback "checkpoint_callback"

checkpoint_filepath = '/content/checkpoints'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
                                    filepath=checkpoint_filepath,
                                    monitor='val_loss',
                                    save_best_only=True,
                                    save_weights_only=True,
                                    mode='max',
                                    verbose=1
                    )

# %% [markdown]
# **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3b
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.01)

lr_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# **Train the model for 40 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3c
### Train the model for 40 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.
history = model.fit(train,
                    epochs=40,
                    validation_data=test,
                    callbacks=[checkpoint_callback, lr_callback])
# Out:
# Epoch 1/40
# 91/91 [==============================] - ETA: 0s - loss: 0.3280 - precision_1: 0.3111 - recall_1: 0.1828
# Epoch 1: val_loss improved from -inf to 0.34460, saving model to /content/checkpoints
# 91/91 [==============================] - 69s 675ms/step - loss: 0.3280 - precision_1: 0.3111 - recall_1: 0.1828 - val_loss: 0.3446 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2596 - precision_1: 0.4710 - recall_1: 0.1662
# Epoch 2: val_loss did not improve from 0.34460
# 91/91 [==============================] - 55s 602ms/step - loss: 0.2596 - precision_1: 0.4710 - recall_1: 0.1662 - val_loss: 0.3317 - val_precision_1: 0.4912 - val_recall_1: 0.0983 - lr: 1.0000e-04
# Epoch 3/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2513 - precision_1: 0.4988 - recall_1: 0.1754
# Epoch 3: val_loss did not improve from 0.34460
# 91/91 [==============================] - 55s 603ms/step - loss: 0.2513 - precision_1: 0.4988 - recall_1: 0.1754 - val_loss: 0.3090 - val_precision_1: 0.5336 - val_recall_1: 0.2714 - lr: 1.0000e-04
# Epoch 4/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2462 - precision_1: 0.5216 - recall_1: 0.1934
# Epoch 4: val_loss did not improve from 0.34460
# 91/91 [==============================] - 56s 622ms/step - loss: 0.2462 - precision_1: 0.5216 - recall_1: 0.1934 - val_loss: 0.3136 - val_precision_1: 0.6759 - val_recall_1: 0.0645 - lr: 1.0000e-04
# Epoch 5/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2442 - precision_1: 0.5247 - recall_1: 0.1916
# Epoch 5: val_loss did not improve from 0.34460
# 91/91 [==============================] - 59s 646ms/step - loss: 0.2442 - precision_1: 0.5247 - recall_1: 0.1916 - val_loss: 0.2940 - val_precision_1: 0.6303 - val_recall_1: 0.1054 - lr: 1.0000e-04
# Epoch 6/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2420 - precision_1: 0.5302 - recall_1: 0.1936
# Epoch 6: val_loss did not improve from 0.34460
# 91/91 [==============================] - 57s 625ms/step - loss: 0.2420 - precision_1: 0.5302 - recall_1: 0.1936 - val_loss: 0.2787 - val_precision_1: 0.5240 - val_recall_1: 0.2502 - lr: 1.0000e-04
# Epoch 7/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2416 - precision_1: 0.5389 - recall_1: 0.2047
# Epoch 7: val_loss did not improve from 0.34460
# 91/91 [==============================] - 57s 623ms/step - loss: 0.2416 - precision_1: 0.5389 - recall_1: 0.2047 - val_loss: 0.2833 - val_precision_1: 0.5610 - val_recall_1: 0.2016 - lr: 1.0000e-04
# Epoch 8/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2402 - precision_1: 0.5386 - recall_1: 0.1986
# Epoch 8: val_loss did not improve from 0.34460
# 91/91 [==============================] - 57s 623ms/step - loss: 0.2402 - precision_1: 0.5386 - recall_1: 0.1986 - val_loss: 0.2690 - val_precision_1: 0.5771 - val_recall_1: 0.1531 - lr: 1.0000e-04
# Epoch 9/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2402 - precision_1: 0.5432 - recall_1: 0.2042
# Epoch 9: val_loss did not improve from 0.34460
# 91/91 [==============================] - 58s 635ms/step - loss: 0.2402 - precision_1: 0.5432 - recall_1: 0.2042 - val_loss: 0.2705 - val_precision_1: 0.6225 - val_recall_1: 0.1122 - lr: 1.0000e-04
# Epoch 10/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2390 - precision_1: 0.5527 - recall_1: 0.2135
# Epoch 10: val_loss did not improve from 0.34460
# 91/91 [==============================] - 57s 629ms/step - loss: 0.2390 - precision_1: 0.5527 - recall_1: 0.2135 - val_loss: 0.2717 - val_precision_1: 0.5669 - val_recall_1: 0.1858 - lr: 1.0000e-04
# Epoch 11/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2390 - precision_1: 0.5479 - recall_1: 0.2074
# Epoch 11: val_loss did not improve from 0.34460
# 91/91 [==============================] - 57s 627ms/step - loss: 0.2390 - precision_1: 0.5479 - recall_1: 0.2074 - val_loss: 0.2632 - val_precision_1: 0.5929 - val_recall_1: 0.1080 - lr: 9.9005e-05
# Epoch 12/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2387 - precision_1: 0.5576 - recall_1: 0.2100
# Epoch 12: val_loss did not improve from 0.34460
# 91/91 [==============================] - 57s 626ms/step - loss: 0.2387 - precision_1: 0.5576 - recall_1: 0.2100 - val_loss: 0.2612 - val_precision_1: 0.5124 - val_recall_1: 0.1881 - lr: 9.8020e-05
# Epoch 13/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2376 - precision_1: 0.5542 - recall_1: 0.2147
# Epoch 13: val_loss did not improve from 0.34460
# 91/91 [==============================] - 59s 653ms/step - loss: 0.2376 - precision_1: 0.5542 - recall_1: 0.2147 - val_loss: 0.2619 - val_precision_1: 0.5650 - val_recall_1: 0.2329 - lr: 9.7045e-05
# Epoch 14/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2370 - precision_1: 0.5660 - recall_1: 0.2192
# Epoch 14: val_loss did not improve from 0.34460
# 91/91 [==============================] - 57s 631ms/step - loss: 0.2370 - precision_1: 0.5660 - recall_1: 0.2192 - val_loss: 0.2558 - val_precision_1: 0.5901 - val_recall_1: 0.2064 - lr: 9.6079e-05
# Epoch 15/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2363 - precision_1: 0.5690 - recall_1: 0.2175
# Epoch 15: val_loss did not improve from 0.34460
# 91/91 [==============================] - 57s 624ms/step - loss: 0.2363 - precision_1: 0.5690 - recall_1: 0.2175 - val_loss: 0.2608 - val_precision_1: 0.5260 - val_recall_1: 0.1993 - lr: 9.5123e-05
# Epoch 16/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2359 - precision_1: 0.5715 - recall_1: 0.2189
# Epoch 16: val_loss did not improve from 0.34460
# 91/91 [==============================] - 55s 609ms/step - loss: 0.2359 - precision_1: 0.5715 - recall_1: 0.2189 - val_loss: 0.2594 - val_precision_1: 0.5341 - val_recall_1: 0.2214 - lr: 9.4176e-05
# Epoch 17/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2354 - precision_1: 0.5815 - recall_1: 0.2210
# Epoch 17: val_loss did not improve from 0.34460
# 91/91 [==============================] - 59s 647ms/step - loss: 0.2354 - precision_1: 0.5815 - recall_1: 0.2210 - val_loss: 0.2548 - val_precision_1: 0.5389 - val_recall_1: 0.2326 - lr: 9.3239e-05
# Epoch 18/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2350 - precision_1: 0.5844 - recall_1: 0.2253
# Epoch 18: val_loss did not improve from 0.34460
# 91/91 [==============================] - 56s 617ms/step - loss: 0.2350 - precision_1: 0.5844 - recall_1: 0.2253 - val_loss: 0.2489 - val_precision_1: 0.5344 - val_recall_1: 0.1946 - lr: 9.2312e-05
# Epoch 19/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2337 - precision_1: 0.6038 - recall_1: 0.2204
# Epoch 19: val_loss did not improve from 0.34460
# 91/91 [==============================] - 56s 618ms/step - loss: 0.2337 - precision_1: 0.6038 - recall_1: 0.2204 - val_loss: 0.2538 - val_precision_1: 0.5235 - val_recall_1: 0.2067 - lr: 9.1393e-05
# Epoch 20/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2327 - precision_1: 0.6058 - recall_1: 0.2271
# Epoch 20: val_loss did not improve from 0.34460
# 91/91 [==============================] - 56s 616ms/step - loss: 0.2327 - precision_1: 0.6058 - recall_1: 0.2271 - val_loss: 0.2522 - val_precision_1: 0.5485 - val_recall_1: 0.2014 - lr: 9.0484e-05
# Epoch 21/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2332 - precision_1: 0.6045 - recall_1: 0.2265
# Epoch 21: val_loss did not improve from 0.34460
# 91/91 [==============================] - 58s 642ms/step - loss: 0.2332 - precision_1: 0.6045 - recall_1: 0.2265 - val_loss: 0.2543 - val_precision_1: 0.5392 - val_recall_1: 0.2228 - lr: 8.9583e-05
# Epoch 22/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2319 - precision_1: 0.6096 - recall_1: 0.2258
# Epoch 22: val_loss did not improve from 0.34460
# 91/91 [==============================] - 56s 619ms/step - loss: 0.2319 - precision_1: 0.6096 - recall_1: 0.2258 - val_loss: 0.2518 - val_precision_1: 0.5733 - val_recall_1: 0.2152 - lr: 8.8692e-05
# Epoch 23/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2309 - precision_1: 0.6112 - recall_1: 0.2276
# Epoch 23: val_loss did not improve from 0.34460
# 91/91 [==============================] - 57s 623ms/step - loss: 0.2309 - precision_1: 0.6112 - recall_1: 0.2276 - val_loss: 0.2535 - val_precision_1: 0.5525 - val_recall_1: 0.2028 - lr: 8.7810e-05
# Epoch 24/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2306 - precision_1: 0.6215 - recall_1: 0.2300
# Epoch 24: val_loss did not improve from 0.34460
# 91/91 [==============================] - 58s 638ms/step - loss: 0.2306 - precision_1: 0.6215 - recall_1: 0.2300 - val_loss: 0.2511 - val_precision_1: 0.5995 - val_recall_1: 0.1978 - lr: 8.6936e-05
# Epoch 25/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2302 - precision_1: 0.6188 - recall_1: 0.2276
# Epoch 25: val_loss did not improve from 0.34460
# 91/91 [==============================] - 59s 647ms/step - loss: 0.2302 - precision_1: 0.6188 - recall_1: 0.2276 - val_loss: 0.2491 - val_precision_1: 0.5504 - val_recall_1: 0.2075 - lr: 8.6071e-05
# Epoch 26/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2294 - precision_1: 0.6271 - recall_1: 0.2335
# Epoch 26: val_loss did not improve from 0.34460
# 91/91 [==============================] - 60s 664ms/step - loss: 0.2294 - precision_1: 0.6271 - recall_1: 0.2335 - val_loss: 0.2498 - val_precision_1: 0.5764 - val_recall_1: 0.2175 - lr: 8.5214e-05
# Epoch 27/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2287 - precision_1: 0.6236 - recall_1: 0.2301
# Epoch 27: val_loss did not improve from 0.34460
# 91/91 [==============================] - 55s 605ms/step - loss: 0.2287 - precision_1: 0.6236 - recall_1: 0.2301 - val_loss: 0.2547 - val_precision_1: 0.5604 - val_recall_1: 0.2184 - lr: 8.4366e-05
# Epoch 28/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2283 - precision_1: 0.6312 - recall_1: 0.2345
# Epoch 28: val_loss did not improve from 0.34460
# 91/91 [==============================] - 55s 602ms/step - loss: 0.2283 - precision_1: 0.6312 - recall_1: 0.2345 - val_loss: 0.2440 - val_precision_1: 0.5892 - val_recall_1: 0.1955 - lr: 8.3527e-05
# Epoch 29/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2279 - precision_1: 0.6319 - recall_1: 0.2368
# Epoch 29: val_loss did not improve from 0.34460
# 91/91 [==============================] - 57s 626ms/step - loss: 0.2279 - precision_1: 0.6319 - recall_1: 0.2368 - val_loss: 0.2522 - val_precision_1: 0.5971 - val_recall_1: 0.1937 - lr: 8.2696e-05
# Epoch 30/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2271 - precision_1: 0.6386 - recall_1: 0.2344
# Epoch 30: val_loss did not improve from 0.34460
# 91/91 [==============================] - 54s 591ms/step - loss: 0.2271 - precision_1: 0.6386 - recall_1: 0.2344 - val_loss: 0.2452 - val_precision_1: 0.6108 - val_recall_1: 0.1996 - lr: 8.1873e-05
# Epoch 31/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2270 - precision_1: 0.6281 - recall_1: 0.2334
# Epoch 31: val_loss did not improve from 0.34460
# 91/91 [==============================] - 55s 602ms/step - loss: 0.2270 - precision_1: 0.6281 - recall_1: 0.2334 - val_loss: 0.2480 - val_precision_1: 0.5965 - val_recall_1: 0.1928 - lr: 8.1058e-05
# Epoch 32/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2270 - precision_1: 0.6298 - recall_1: 0.2349
# Epoch 32: val_loss did not improve from 0.34460
# 91/91 [==============================] - 54s 593ms/step - loss: 0.2270 - precision_1: 0.6298 - recall_1: 0.2349 - val_loss: 0.2467 - val_precision_1: 0.6056 - val_recall_1: 0.2170 - lr: 8.0252e-05
# Epoch 33/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2257 - precision_1: 0.6325 - recall_1: 0.2364
# Epoch 33: val_loss did not improve from 0.34460
# 91/91 [==============================] - 57s 632ms/step - loss: 0.2257 - precision_1: 0.6325 - recall_1: 0.2364 - val_loss: 0.2527 - val_precision_1: 0.5486 - val_recall_1: 0.2078 - lr: 7.9453e-05
# Epoch 34/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2253 - precision_1: 0.6387 - recall_1: 0.2381
# Epoch 34: val_loss did not improve from 0.34460
# 91/91 [==============================] - 55s 602ms/step - loss: 0.2253 - precision_1: 0.6387 - recall_1: 0.2381 - val_loss: 0.2485 - val_precision_1: 0.5774 - val_recall_1: 0.2019 - lr: 7.8663e-05
# Epoch 35/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2252 - precision_1: 0.6423 - recall_1: 0.2412
# Epoch 35: val_loss did not improve from 0.34460
# 91/91 [==============================] - 55s 606ms/step - loss: 0.2252 - precision_1: 0.6423 - recall_1: 0.2412 - val_loss: 0.2456 - val_precision_1: 0.5642 - val_recall_1: 0.2225 - lr: 7.7880e-05
# Epoch 36/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2245 - precision_1: 0.6411 - recall_1: 0.2435
# Epoch 36: val_loss did not improve from 0.34460
# 91/91 [==============================] - 55s 605ms/step - loss: 0.2245 - precision_1: 0.6411 - recall_1: 0.2435 - val_loss: 0.2426 - val_precision_1: 0.5923 - val_recall_1: 0.2049 - lr: 7.7105e-05
# Epoch 37/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2243 - precision_1: 0.6419 - recall_1: 0.2463
# Epoch 37: val_loss did not improve from 0.34460
# 91/91 [==============================] - 55s 606ms/step - loss: 0.2243 - precision_1: 0.6419 - recall_1: 0.2463 - val_loss: 0.2419 - val_precision_1: 0.6290 - val_recall_1: 0.1752 - lr: 7.6338e-05
# Epoch 38/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2232 - precision_1: 0.6490 - recall_1: 0.2450
# Epoch 38: val_loss did not improve from 0.34460
# 91/91 [==============================] - 56s 621ms/step - loss: 0.2232 - precision_1: 0.6490 - recall_1: 0.2450 - val_loss: 0.2480 - val_precision_1: 0.5475 - val_recall_1: 0.1966 - lr: 7.5578e-05
# Epoch 39/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2224 - precision_1: 0.6445 - recall_1: 0.2449
# Epoch 39: val_loss did not improve from 0.34460
# 91/91 [==============================] - 54s 600ms/step - loss: 0.2224 - precision_1: 0.6445 - recall_1: 0.2449 - val_loss: 0.2423 - val_precision_1: 0.6080 - val_recall_1: 0.2064 - lr: 7.4826e-05
# Epoch 40/40
# 91/91 [==============================] - ETA: 0s - loss: 0.2222 - precision_1: 0.6500 - recall_1: 0.2466
# Epoch 40: val_loss did not improve from 0.34460
# 91/91 [==============================] - 56s 613ms/step - loss: 0.2222 - precision_1: 0.6500 - recall_1: 0.2466 - val_loss: 0.2473 - val_precision_1: 0.5838 - val_recall_1: 0.2052 - lr: 7.4082e-05

# %% [markdown]
# # Model Evaluation
#
# **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the models performance.**

# %%
# CodeGrade Tag Ex4a

# Plot Training and Validation Loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Precision Metrics
plt.plot(history.history['precision'], label='Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.title('Precision Metrics')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend()

# Plot Recall Metrics
plt.plot(history.history['recall'], label='Recall')
plt.plot(history.history['val_recall'], label='Validation Recall')
plt.title('Recall Metrics')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend()

plt.show()

# %% [markdown]
# **Load the best weights from your model checkpoint, and create plots demonstrating the classification perfomnce of the model. Be sure to demonstrate the results of the multi-label classification, comparing the top three most probable genres predicted with the ground truth genres for each poster. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %%
# CodeGrade Tag Ex4b
# Load the best model weights
model.load_weights(checkpoint_filepath)

# Predict genre probabilities for each poster in the test dataset
predictions = model.predict(test)

# Prepare other necessary data
true_labels = labels_test
genre_names = genres

# Determine top 3 predicted genres for each poster
top_3_predicted_indices = np.argsort(predictions, axis=1)[:, -3:]

def plot_classification_performance(index, true_labels, genre_names, predictions, top_3_predicted_indices):
    # Display the poster image
    poster = tf.image.decode_jpeg(tf.io.read_file(img_locs_test[0][index]))
    plt.imshow(poster)
    plt.axis('off')
    plt.title('Movie Poster')
    plt.show()

    # Ground truth genres
    true_genre_indices = np.where(true_labels[index] == 1)[0]
    true_genres = [genre_names[i] for i in true_genre_indices]

    # Predicted genres
    predicted_genre_indices = top_3_predicted_indices[index]
    predicted_genres = [genre_names[i] for i in predicted_genre_indices]

    # Print true and predicted genres
    print('True Genres:', true_genres)
    print('Predicted Genres:', predicted_genres)

def plot_genre_comparison(index, true_labels, genre_names, predictions, top_3_predicted_indices):
    # Get the top 3 predictions for the current poster
    top3_pred_indices = top_3_predicted_indices[index]
    top3_pred_values = predictions[index][top3_pred_indices]
    top3_pred_genres = [genre_names[i] for i in top3_pred_indices]

    # Get the ground truth genres for the current poster
    true_genres_indices = np.where(true_labels[index] == 1)[0]
    true_genres = [genre_names[i] for i in true_genres_indices]

    # Create a new plot for each poster
    plt.figure(figsize=(6, 4))
    index = np.arange(len(top3_pred_genres))
    bar_width = 0.3

    # Plot predicted genres
    plt.bar(index, top3_pred_values, bar_width, label='Predicted')

    # Plot ground truth genres
    if true_genres:
        true_values = [1 if genre in true_genres else 0 for genre in top3_pred_genres]
        plt.bar(index + bar_width, true_values, bar_width, label='Actual', color='orange')

    plt.xlabel('Genres')
    plt.ylabel('Probabilities')
    plt.title('Top 3 Predicted vs Actual Genres for Poster {}'.format(i + 1))
    plt.xticks(index + bar_width / 2, top3_pred_genres, rotation=45)
    plt.ylim([0, 1])
    plt.legend()
    plt.tight_layout()
    plt.show()

# Plot classification performances for the first 5 posters
num_posters = min(20, len(true_labels))
for i in range(num_posters):
    plot_classification_performance(i, true_labels, genre_names, predictions, top_3_predicted_indices)

# Plot genre comparison for the first 5 posters
for i in range(num_posters):
    plot_genre_comparison(i, true_labels, genre_names, predictions, top_3_predicted_indices)
# Out:
# 23/23 [==============================] - 7s 306ms/step
# True Genres: ['Crime', 'Thriller']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Crime', 'Drama', 'Mystery']
# Predicted Genres: ['Action', 'Drama', 'Comedy']
# True Genres: ['Action', 'Adventure', 'Fantasy']
# Predicted Genres: ['Action', 'Drama', 'Comedy']
# True Genres: ['Horror']
# Predicted Genres: ['Action', 'Drama', 'Comedy']
# True Genres: ['Comedy', 'Romance']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Adventure', 'Comedy', 'Crime']
# Predicted Genres: ['Action', 'Drama', 'Comedy']
# True Genres: ['Crime', 'Mystery', 'Thriller']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Action', 'Sci-Fi', 'Thriller']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Comedy', 'Family', 'Fantasy']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Action', 'Adventure', 'Thriller']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Action', 'Drama', 'Musical']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Action', 'Adventure', 'Sci-Fi']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Comedy']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Comedy']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Comedy', 'Drama']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Crime', 'Drama', 'History']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Drama', 'Music']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
# True Genres: ['Action', 'Romance', 'Thriller']
# Predicted Genres: ['Action', 'Drama', 'Comedy']
# True Genres: ['Drama']
# Predicted Genres: ['Action', 'Drama', 'Comedy']
# True Genres: ['Comedy', 'Drama', 'Romance']
# Predicted Genres: ['Action', 'Comedy', 'Drama']
